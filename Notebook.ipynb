# %%
from plotter import Plotter
plotter = Plotter("data.json")

# %%
plotter.draw_plots()
# Out:
# ['Graphics/corners.png', 'Graphics/deviation.png']

# %%
from IPython.display import display
for plot in plotter.plots:
    display(plot)
# Out:
# 'Graphics/corners.png'
# 'Graphics/deviation.png'
